# %% [markdown]
# # Data Exploration
#
# In this notebook describe your data exploration steps.

# %% [markdown]
# ## Install dependencies

# %%
# %pip install pandas
# %pip install SQLAlchemy==1.4.46
# %pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\martin\appdata\roaming\python\python310\site-packages (2.0.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\martin\appdata\roaming\python\python310\site-packages (from pandas) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\martin\appdata\roaming\python\python310\site-packages (from pandas) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\program files\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\martin\appdata\roaming\python\python310\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in c:\program files\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: SQLAlchemy==1.4.46 in c:\program files\python310\lib\site-packages (1.4.46)
# Requirement already satisfied: greenlet!=0.4.17 in c:\program files\python310\lib\site-packages (from SQLAlchemy==1.4.46) (2.0.2)
# [notice] A new release of pip available: 22.2.2 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\martin\appdata\roaming\python\python310\site-packages (3.7.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\martin\appdata\roaming\python\python310\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\martin\appdata\roaming\python\python310\site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\martin\appdata\roaming\python\python310\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\martin\appdata\roaming\python\python310\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\martin\appdata\roaming\python\python310\site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\martin\appdata\roaming\python\python310\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\martin\appdata\roaming\python\python310\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\martin\appdata\roaming\python\python310\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\program files\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\program files\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Load data

# %%
import pandas as pd
import numpy as np

df_TPZ = pd.read_sql_table('TPZ_data', 'sqlite:///data/preprocessed-data.db')
df_EmZ = pd.read_sql_table('EmZ_data', 'sqlite:///data/preprocessed-data.db')
df_bikes = pd.read_sql_table('source2_data', 'sqlite:///data/preprocessed-data.db')

# %% [markdown]
# ### Look at the first rows

# %%
df_EmZ.head(10)
# Out:
#         Datum           Zeit  EmZCH   EmZD  Unnamed: 4  Unnamed: 5
# 0  01.07.2020  00:00 - 01:00   47.0   24.0         NaN         NaN  \
# 1  01.07.2020  01:00 - 02:00   19.0    5.0         NaN         NaN
# 2  01.07.2020  02:00 - 03:00   14.0    8.0         NaN         NaN
# 3  01.07.2020  03:00 - 04:00    6.0    1.0         NaN         NaN
# 4  01.07.2020  04:00 - 05:00   21.0    2.0         NaN         NaN
# 5  01.07.2020  05:00 - 06:00   67.0   21.0         NaN         NaN
# 6  01.07.2020  06:00 - 07:00  207.0   48.0         NaN         NaN
# 7  01.07.2020  07:00 - 08:00  271.0  117.0         NaN         NaN
# 8  01.07.2020  08:00 - 09:00  214.0  243.0         NaN         NaN
# 9  01.07.2020  09:00 - 10:00  236.0  297.0         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10 Start Time
# 0         NaN         NaN         NaN         NaN          NaN      00:00  \
# 1         NaN         NaN         NaN         NaN          NaN      01:00
# 2         NaN         NaN         NaN         NaN          NaN      02:00
# 3         NaN         NaN         NaN         NaN          NaN      03:00
# 4         NaN         NaN         NaN         NaN          NaN      04:00
# 5         NaN         NaN         NaN         NaN          NaN      05:00
# 6         NaN         NaN         NaN         NaN          NaN      06:00
# 7         NaN         NaN         NaN         NaN          NaN      07:00
# 8         NaN         NaN         NaN         NaN          NaN      08:00
# 9         NaN         NaN         NaN         NaN          NaN      09:00
#
#   End Time      Start DateTime        End DateTime
# 0    01:00 2020-07-01 00:00:00 2020-07-01 01:00:00
# 1    02:00 2020-07-01 01:00:00 2020-07-01 02:00:00
# 2    03:00 2020-07-01 02:00:00 2020-07-01 03:00:00
# 3    04:00 2020-07-01 03:00:00 2020-07-01 04:00:00
# 4    05:00 2020-07-01 04:00:00 2020-07-01 05:00:00
# 5    06:00 2020-07-01 05:00:00 2020-07-01 06:00:00
# 6    07:00 2020-07-01 06:00:00 2020-07-01 07:00:00
# 7    08:00 2020-07-01 07:00:00 2020-07-01 08:00:00
# 8    09:00 2020-07-01 08:00:00 2020-07-01 09:00:00
# 9    10:00 2020-07-01 09:00:00 2020-07-01 10:00:00

# %%
df_EmZ.head(10)
# Out:
#         Datum           Zeit  EmZCH   EmZD  Unnamed: 4  Unnamed: 5
# 0  01.07.2020  00:00 - 01:00   47.0   24.0         NaN         NaN  \
# 1  01.07.2020  01:00 - 02:00   19.0    5.0         NaN         NaN
# 2  01.07.2020  02:00 - 03:00   14.0    8.0         NaN         NaN
# 3  01.07.2020  03:00 - 04:00    6.0    1.0         NaN         NaN
# 4  01.07.2020  04:00 - 05:00   21.0    2.0         NaN         NaN
# 5  01.07.2020  05:00 - 06:00   67.0   21.0         NaN         NaN
# 6  01.07.2020  06:00 - 07:00  207.0   48.0         NaN         NaN
# 7  01.07.2020  07:00 - 08:00  271.0  117.0         NaN         NaN
# 8  01.07.2020  08:00 - 09:00  214.0  243.0         NaN         NaN
# 9  01.07.2020  09:00 - 10:00  236.0  297.0         NaN         NaN
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10 Start Time
# 0         NaN         NaN         NaN         NaN          NaN      00:00  \
# 1         NaN         NaN         NaN         NaN          NaN      01:00
# 2         NaN         NaN         NaN         NaN          NaN      02:00
# 3         NaN         NaN         NaN         NaN          NaN      03:00
# 4         NaN         NaN         NaN         NaN          NaN      04:00
# 5         NaN         NaN         NaN         NaN          NaN      05:00
# 6         NaN         NaN         NaN         NaN          NaN      06:00
# 7         NaN         NaN         NaN         NaN          NaN      07:00
# 8         NaN         NaN         NaN         NaN          NaN      08:00
# 9         NaN         NaN         NaN         NaN          NaN      09:00
#
#   End Time      Start DateTime        End DateTime
# 0    01:00 2020-07-01 00:00:00 2020-07-01 01:00:00
# 1    02:00 2020-07-01 01:00:00 2020-07-01 02:00:00
# 2    03:00 2020-07-01 02:00:00 2020-07-01 03:00:00
# 3    04:00 2020-07-01 03:00:00 2020-07-01 04:00:00
# 4    05:00 2020-07-01 04:00:00 2020-07-01 05:00:00
# 5    06:00 2020-07-01 05:00:00 2020-07-01 06:00:00
# 6    07:00 2020-07-01 06:00:00 2020-07-01 07:00:00
# 7    08:00 2020-07-01 07:00:00 2020-07-01 08:00:00
# 8    09:00 2020-07-01 08:00:00 2020-07-01 09:00:00
# 9    10:00 2020-07-01 09:00:00 2020-07-01 10:00:00

# %%
df_bikes.head(10)
# Out:
#                  Zeit  FahrradbrueckeFahrradbruecke
# 0 2020-01-01 00:00:00                         104.0  \
# 1 2020-01-01 01:00:00                         128.0
# 2 2020-01-01 02:00:00                         178.0
# 3 2020-01-01 03:00:00                         113.0
# 4 2020-01-01 04:00:00                          76.0
# 5 2020-01-01 05:00:00                          50.0
# 6 2020-01-01 06:00:00                          25.0
# 7 2020-01-01 07:00:00                          19.0
# 8 2020-01-01 08:00:00                          23.0
# 9 2020-01-01 09:00:00                          27.0
#
#    FahrradbrueckeFahrradbruecke stadteinwärts Fahrräder
# 0                                               31.0     \
# 1                                               47.0
# 2                                               77.0
# 3                                               56.0
# 4                                               36.0
# 5                                               12.0
# 6                                               14.0
# 7                                                6.0
# 8                                               11.0
# 9                                               13.0
#
#    FahrradbrueckeFahrradbruecke stadtauswärts Fahrräder   Symbol Wetter
# 0                                               73.0     Leicht bewölkt  \
# 1                                               81.0     Leicht bewölkt
# 2                                              101.0             Sonnig
# 3                                               57.0             Sonnig
# 4                                               40.0             Sonnig
# 5                                               38.0             Sonnig
# 6                                               11.0             Sonnig
# 7                                               13.0             Sonnig
# 8                                               12.0             Sonnig
# 9                                               14.0             Sonnig
#
#    Temperatur (°C)  Gefühlte Temperatur (°C)  Regen (mm)  Unnamed: 0
# 0              1.0                      -1.0         0.0         NaN  \
# 1              0.0                      -1.0         0.0         NaN
# 2              0.0                      -2.0         0.0         NaN
# 3              0.0                      -2.0         0.0         NaN
# 4              0.0                      -2.0         0.0         NaN
# 5              0.0                      -2.0         0.0         NaN
# 6             -1.0                      -3.0         0.0         NaN
# 7              0.0                      -2.0         0.0         NaN
# 8              1.0                      -1.0         0.0         NaN
# 9              1.0                       0.0         0.0         NaN
#
#    Unnamed: 9
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN

# %% [markdown]
# ### Data exploration
# Print some basic information about the data. Your data exploration would continue here.

# %%
df_bikes.info()

df_bikes['Symbol Wetter'].unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17545 entries, 0 to 17544
# Data columns (total 10 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Zeit                                                  17545 non-null  datetime64[ns]
#  1   FahrradbrueckeFahrradbruecke                          17442 non-null  float64
#  2   FahrradbrueckeFahrradbruecke stadteinwärts Fahrräder  17442 non-null  float64
#  3   FahrradbrueckeFahrradbruecke stadtauswärts Fahrräder  17442 non-null  float64
#  4   Symbol Wetter                                         17545 non-null  object
#  5   Temperatur (°C)                                       17543 non-null  float64
#  6   Gefühlte Temperatur (°C)                              17543 non-null  float64
#  7   Regen (mm)                                            17543 non-null  float64
#  8   Unnamed: 0                                            0 non-null      float64
#  9   Unnamed: 9                                            0 non-null      float64
# dtypes: datetime64[ns](1), float64(8), object(1)
# memory usage: 1.3+ MB
# array(['Leicht bewölkt', 'Sonnig', 'Bewölkt', 'Bedeckt',
#        'Leichter Regenfall', 'Nieselregen', 'Stellenweiser Regenfall',
#        'Mäßiger Regenfall', 'Leichte Eisregen', 'Leichter Schneefall',
#        'Starker Schneefall', 'Stellenweise starker Schneefall',
#        'Leichte Schneeschauer', 'Mäßige bis starke Schneefälle',
#        'Stellenweiser Nieselregen',
#        'Mäßiger bis starker Regen mit Gewitter',
#        'Mäßiger bis starker Eisregen',
#        'Mäßiger bis starker Schneefall mit Gewitter', 'Leichter Eisregen',
#        'Leichter Regenschauer', 'Stellenweiser leichter Regenfall',
#        'Stellenweise Gewitter und Niederschläge',
#        'Stellenweiser Schneefall', 'Starker Regenfall',
#        'Teilweise mäßiger Regenfall', 'Stellenweiser Eisregen',
#        'Leichter Nebel', 'Schneesturm',
#        'Stellenweise leichter Schneefall', 'weather_condition_null',
#        'Mäßiger Schneefall', 'Nieselregen mit Gewitter',
#        'Mäßiger bis starker Regenschauer', 'Nebel',
#        'Sintflutartiger Regenfall', 'Teilweise starker Regenfall',
#        'Mäßiger bis starker gefrierender Regen',
#        'Stellenweise mäßiger Schneefall', 'Mäßige bis starke Eisregen'],
#       dtype=object)

# %%
df_EmZ.info()

df_EmZ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15360 entries, 0 to 15359
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Datum           15336 non-null  object
#  1   Zeit            15336 non-null  object
#  2   EmZCH           15336 non-null  float64
#  3   EmZD            15336 non-null  float64
#  4   Unnamed: 4      0 non-null      float64
#  5   Unnamed: 5      0 non-null      float64
#  6   Unnamed: 6      0 non-null      float64
#  7   Unnamed: 7      0 non-null      float64
#  8   Unnamed: 8      0 non-null      float64
#  9   Unnamed: 9      0 non-null      float64
#  10  Unnamed: 10     0 non-null      float64
#  11  Start Time      15336 non-null  object
#  12  End Time        15336 non-null  object
#  13  Start DateTime  15336 non-null  datetime64[ns]
#  14  End DateTime    15336 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(9), object(4)
# memory usage: 1.8+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15360 entries, 0 to 15359
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Datum           15336 non-null  object
#  1   Zeit            15336 non-null  object
#  2   EmZCH           15336 non-null  float64
#  3   EmZD            15336 non-null  float64
#  4   Unnamed: 4      0 non-null      float64
#  5   Unnamed: 5      0 non-null      float64
#  6   Unnamed: 6      0 non-null      float64
#  7   Unnamed: 7      0 non-null      float64
#  8   Unnamed: 8      0 non-null      float64
#  9   Unnamed: 9      0 non-null      float64
#  10  Unnamed: 10     0 non-null      float64
#  11  Start Time      15336 non-null  object
#  12  End Time        15336 non-null  object
#  13  Start DateTime  15336 non-null  datetime64[ns]
#  14  End DateTime    15336 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(9), object(4)
# memory usage: 1.8+ MB

# %% [markdown]
# #### Find faulty sections by plotting the data.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14,6))
plt.plot(df_bikes['Zeit'], df_bikes['FahrradbrueckeFahrradbruecke'], label='Fahrradbruecke')
plt.plot(df_bikes['Zeit'], df_bikes['Temperatur (°C)'], label='Temperatur')
plt.xlabel('Time')
plt.ylabel('Amount of cyclists')
plt.legend()
plt.title('Time Series Plot')
plt.show()

df_bikes.plot()
plt.show()

### Show daily aggregation

plt.figure(figsize=(14,6))

# Convert 'Start DateTime' to datetime if it's not already
df_bikes['Zeit'] = pd.to_datetime(df_bikes['Zeit'])

# Set 'Start DateTime' as the index
df = df_bikes.set_index('Zeit')

# Select only the columns to resample
df_to_resample = df[['FahrradbrueckeFahrradbruecke', 'FahrradbrueckeFahrradbruecke stadteinwärts Fahrräder', 'FahrradbrueckeFahrradbruecke stadtauswärts Fahrräder']]

# Resample and aggregate by day
df_daily = df_to_resample.resample('D').sum()

plt.plot(df_daily.index, df_daily['FahrradbrueckeFahrradbruecke'], label='Fahrradbruecke', linestyle='solid')
plt.plot(df_daily.index, df_daily['FahrradbrueckeFahrradbruecke stadteinwärts Fahrräder'], label='stadteinwärts', linestyle='solid')
plt.plot(df_daily.index, df_daily['FahrradbrueckeFahrradbruecke stadtauswärts Fahrräder'], label='stadtauswärts', linestyle='solid')

plt.xlabel('Time')
plt.ylabel('Cyclists Count')
plt.legend()
plt.title('Time Series Plot (Daily Aggregate)')
plt.show()

plt.figure(figsize=(14,6))

# Filter data for the specific day
df_day = df[df.index.date == pd.to_datetime('2021-01-15').date()]

plt.plot(df_day.index, df_day['FahrradbrueckeFahrradbruecke'], label='Fahrradbruecke', linestyle='solid')
plt.plot(df_day.index, df_day['FahrradbrueckeFahrradbruecke stadteinwärts Fahrräder'], label='stadteinwärts', linestyle='solid')
plt.plot(df_day.index, df_day['FahrradbrueckeFahrradbruecke stadtauswärts Fahrräder'], label='stadtauswärts', linestyle='solid')

plt.xlabel('Time')
plt.ylabel('Count')
plt.legend()
plt.title('Time Series Plot for 2021-01-15')
plt.show()

# %% [markdown]
# There is a known problem in 2021 with the bike counter. Find the exact timeframe:

# %%
df = df_bikes

bike_columns = ['FahrradbrueckeFahrradbruecke', 'FahrradbrueckeFahrradbruecke stadteinwärts Fahrräder', 'FahrradbrueckeFahrradbruecke stadtauswärts Fahrräder']

# Defining the steep drop
steep_drop_before = ((df[bike_columns].diff().abs() > 50) & (df[bike_columns] == 0)).any(axis=1)
steep_drop_after = ((df[bike_columns].diff(-1).abs() > 50) & (df[bike_columns] == 0)).any(axis=1)

# Defining the sequences of at least 3 consecutive zeros
consecutive_zeros = df[bike_columns].rolling(window=3).apply(lambda x: np.all(x == 0), raw=True).all(axis=1)

# row without any date
all_na = df[bike_columns].isna().all(axis=1)

# Combining the two conditions
df['faulty'] = steep_drop_before | steep_drop_after | consecutive_zeros | all_na

# Find the start and end times of the faulty periods
faulty_periods = df.loc[df['faulty'] != df['faulty'].shift().fillna(False), ['Zeit', 'faulty']]

# Create dataframes for start and end times separately
start_times = faulty_periods.loc[faulty_periods['faulty'], 'Zeit']
end_times = faulty_periods.loc[~faulty_periods['faulty'], 'Zeit']

# If the last period is faulty and has no end, add the last timestamp of df as its end
if len(start_times) > len(end_times):
    end_times.loc[len(end_times)] = df['Zeit'].iloc[-1]

# Print start and end times
for start, end in zip(start_times, end_times):
    print(f"Faulty period started at {start} and ended at {end}")
# Out:
# Faulty period started at 2020-01-01 00:00:00 and ended at 2020-01-01 02:00:00
# Faulty period started at 2020-03-29 03:00:00 and ended at 2020-03-29 05:00:00
# Faulty period started at 2020-05-07 10:00:00 and ended at 2020-05-07 11:00:00
# Faulty period started at 2020-08-17 05:00:00 and ended at 2020-08-17 06:00:00
# Faulty period started at 2021-03-28 03:00:00 and ended at 2021-03-28 05:00:00
# Faulty period started at 2021-05-28 13:00:00 and ended at 2021-05-28 14:00:00
# Faulty period started at 2021-05-28 15:00:00 and ended at 2021-06-02 15:00:00
# Faulty period started at 2021-08-25 12:00:00 and ended at 2021-08-25 13:00:00
# Faulty period started at 2021-08-25 14:00:00 and ended at 2021-09-30 14:00:00

# %% [markdown]
# More then one faulty timeframe have been detected. The start time is included, the end time excluded.

# %% [markdown]
# ### Some more Plots

# %% [markdown]
# #### Scatter Plot analyzing relation between rain and Temperature

# %%
plt.figure(figsize=(6,6))
plt.scatter(df_bikes['Temperatur (°C)'], df_bikes['Regen (mm)'])
plt.xlabel('Temperatur (°C)')
plt.ylabel('Regen (mm)')
plt.title('Scatter Plot')
plt.show()

# %% [markdown]
# ### TPZ Plots

# %%
plt.figure(figsize=(14,6))

# Convert 'Start DateTime' to datetime if it's not already
df_TPZ['Start DateTime'] = pd.to_datetime(df_TPZ['Start DateTime'])

# Set 'Start DateTime' as the index
df = df_TPZ.set_index('Start DateTime')

# Sort data by 'Start DateTime' before plotting
df_sorted = df.sort_values('Start DateTime')

# Select only the columns to resample
df_to_resample = df_sorted[['TPZCH', 'TPZD']]

# Resample and aggregate by day
df_daily = df_to_resample.resample('D').sum()

plt.plot(df_daily.index, df_daily['TPZCH'], label='TPZCH', linestyle='solid')
plt.plot(df_daily.index, df_daily['TPZD'], label='TPZD', linestyle='solid')

plt.xlabel('Start DateTime')
plt.ylabel('Count')
plt.legend()
plt.title('Time Series Plot (Daily Aggregate)')
plt.show()

plt.figure(figsize=(14,6))

# Filter data for the specific day
df_day = df[df.index.date == pd.to_datetime('2021-01-15').date()]

plt.plot(df_day.index, df_day['TPZCH'], label='TPZCH', linestyle='solid')
plt.plot(df_day.index, df_day['TPZD'], label='TPZD', linestyle='solid')

plt.xlabel('Time')
plt.ylabel('Count')
plt.legend()
plt.title('Time Series Plot for 2021-01-15')
plt.show()

# %% [markdown]
# ### EmZ Plots

# %%
plt.figure(figsize=(14,6))

# Convert 'Start DateTime' to datetime if it's not already
df_EmZ['Start DateTime'] = pd.to_datetime(df_EmZ['Start DateTime'])

# Set 'Start DateTime' as the index
df = df_EmZ.set_index('Start DateTime')

# Sort data by 'Start DateTime' before plotting
df_sorted = df.sort_values('Start DateTime')

# Select only the columns to resample
df_to_resample = df_sorted[['EmZCH', 'EmZD']]

# Resample and aggregate by day
df_daily = df_to_resample.resample('D').sum()

plt.plot(df_daily.index, df_daily['EmZCH'], label='EmZCH', linestyle='solid')
plt.plot(df_daily.index, df_daily['EmZD'], label='EmZD', linestyle='solid')

plt.xlabel('Start DateTime')
plt.ylabel('Count')
plt.legend()
plt.title('Time Series Plot (Daily Aggregate)')
plt.show()

plt.figure(figsize=(14,6))

# Filter data for the specific day
df_day = df[df.index.date == pd.to_datetime('2021-01-15').date()]

plt.plot(df_day.index, df_day['EmZCH'], label='EmZCH', linestyle='solid')
plt.plot(df_day.index, df_day['EmZD'], label='EmZD', linestyle='solid')

plt.xlabel('Time')
plt.ylabel('Count')
plt.legend()
plt.title('Time Series Plot for 2021-01-15')
plt.show()
